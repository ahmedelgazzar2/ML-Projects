# %%
# !pip install kaggle

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %%
# !export KAGGLE_API_TOKEN=KGAT_30da3c1811d50838e2d46acd4e26155e

# %%
# !mkdir -p ~/.kaggle && echo KGAT_30da3c1811d50838e2d46acd4e26155e > ~/.kaggle/access_token && chmod 600 ~/.kaggle/access_token
